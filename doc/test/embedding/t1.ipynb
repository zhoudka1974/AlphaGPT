# %%
from torchtext.vocab import GloVe

glove = GloVe(name='6B',dim=300)
# Out:
# c:\workenv\code\AlphaGPT\venv\Lib\site-packages\torchtext\__init__.py:7: SyntaxWarning: invalid escape sequence '\ '
#   "\n/!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\ \n"
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\workenv\code\AlphaGPT\venv\Lib\site-packages\torch\_ops.py:1442, in _Ops.load_library(self, path)
#    1441 try:
# -> 1442     ctypes.CDLL(path)
#    1443 except Exception as e:
#
# File C:\tools\installed\Python312\Lib\ctypes\__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#
# OSError: [WinError 127] 找不到指定的程序。
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ...
